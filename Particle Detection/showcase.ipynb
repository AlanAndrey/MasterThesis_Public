# %%
import pims
import numpy as np
from matplotlib import pyplot as plt

import sys
import os

# Add the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('showcase.ipynb'), '..')))

from Cilia import locate_particles

topdir = 'C:/Users/alana/iCloudDrive/UNIBE/Master Thesis/Data/videos/Alan_16_08_24'
file = topdir + '/1/500nm-08162024142959-0.tiff'

# %%
image = np.array(pims.open(file))[0]
#image = image[200:300,125:225]
result, new_image, kernel = locate_particles(image, 0.1, 20, 10, dark_particles=True)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30, 10))
im1 = ax1.imshow(new_image, cmap='gray')
fig.colorbar(im1, ax=ax1, shrink=0.7)
im2 = ax2.imshow(result)
fig.colorbar(im2, ax=ax2, shrink=0.7)
im3 = ax3.imshow(kernel)
fig.colorbar(im3, ax=ax3, shrink=0.7)
